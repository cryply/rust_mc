// %%
:dep serde = { version = "1.0", features = ["derive"] }
:dep rand = "0.8"
:dep polars = { version = "0.46.0", features = ["lazy", "describe"] }
:dep plotters = { version = "0.3.6", default-features = false, features = ["evcxr", "all_series", "all_elements"] }

// %%
use polars::prelude::*;
use plotters::prelude::*;
use std::fs::*;

let empty = DataFrame::default();

let mut fruits = df!(
    "fruit" => [
        "apple", "banana", "orange",
        "apple", "banana", "orange",
        "apple", "banana", "orange",
        "apple", "banana", "orange",
        "apple", "banana", "orange",               
               ] ,
    "year"  => [
        2018, 2019, 2020, 2021, 2022,
        2018, 2019, 2020, 2021, 2022,
        2018, 2019, 2020, 2021, 2022,
               ],
    "price" => [1.5, 1.7, 1.2, 1.0, 1.6, 
                0.8, 0.7, 0.9, 0.6, 0.8, 
                2.0, 2.3, 1.9, 2.5, 2.3]
)?;

println!("{:?}", fruits[0]);

println!("{:?}", fruits["year"]);
// Out:
// Series(SeriesColumn { inner: shape: (15,)
// Series: 'fruit' [str]
// [
// 	"apple"
// 	"banana"
// 	"orange"
// 	"apple"
// 	"banana"
// 	…
// 	"banana"
// 	"orange"
// 	"apple"
// 	"banana"
// 	"orange"
// ], materialized_at: None })
// Series(SeriesColumn { inner: shape: (15,)
// Series: 'year' [i32]
// [
// 	2018
// 	2019
// 	2020
// 	2021
// 	2022
// 	…
// 	2018
// 	2019
// 	2020
// 	2021
// 	2022
// ], materialized_at: None })

// %% [markdown]
// Import Polars and load the included fruits.csv dataset

// %%
let mut file = File::create("fruits.csv").expect("could not create file");

CsvWriter::new(&mut file)
    .include_header(true)
    .with_separator(b',')
    .finish(&mut fruits)?;

let df_csv = CsvReadOptions::default()
    .with_has_header(true)
    .with_parse_options(CsvParseOptions::default().with_try_parse_dates(true))
    .try_into_reader_with_file_path(Some("fruits.csv".into()))?
    .finish()?;

df_csv.shape()
// Out:
// (15, 3)

// %% [markdown]
// Explore the data with .head(), .describe(), and groupby aggregations

// %%
println!("Head: {}", df_csv.head(Some(2)));
println!("Tail: {}", df_csv.tail(Some(2)));

let mut sl: DataFrame = df_csv.slice(2,3);
println!("Slice:2:3 {}", sl);

sl.apply_at_idx(2, |s| s + 100);
println!("Apply at index +100 to price: {}", sl);
// Out:
// Head: shape: (2, 3)
// ┌────────┬──────┬───────┐
// │ fruit  ┆ year ┆ price │
// │ ---    ┆ ---  ┆ ---   │
// │ str    ┆ i64  ┆ f64   │
// ╞════════╪══════╪═══════╡
// │ apple  ┆ 2018 ┆ 1.5   │
// │ banana ┆ 2019 ┆ 1.7   │
// └────────┴──────┴───────┘
// Tail: shape: (2, 3)
// ┌────────┬──────┬───────┐
// │ fruit  ┆ year ┆ price │
// │ ---    ┆ ---  ┆ ---   │
// │ str    ┆ i64  ┆ f64   │
// ╞════════╪══════╪═══════╡
// │ banana ┆ 2021 ┆ 2.5   │
// │ orange ┆ 2022 ┆ 2.3   │
// └────────┴──────┴───────┘
// Slice:2:3 shape: (3, 3)
// ┌────────┬──────┬───────┐
// │ fruit  ┆ year ┆ price │
// │ ---    ┆ ---  ┆ ---   │
// │ str    ┆ i64  ┆ f64   │
// ╞════════╪══════╪═══════╡
// │ orange ┆ 2020 ┆ 1.2   │
// │ apple  ┆ 2021 ┆ 1.0   │
// │ banana ┆ 2022 ┆ 1.6   │
// └────────┴──────┴───────┘
// Apply at index +100 to price: shape: (3, 3)
// ┌────────┬──────┬───────┐
// │ fruit  ┆ year ┆ price │
// │ ---    ┆ ---  ┆ ---   │
// │ str    ┆ i64  ┆ f64   │
// ╞════════╪══════╪═══════╡
// ...

// %%
let summary = df_csv
    .clone()
    .lazy()
    .select([
        col("price").count().alias("count"),
        col("price").null_count().alias("null_count"),
        col("price").mean().alias("mean"),
        col("price").std(1).alias("std"),
        col("price").min().alias("min"),
        col("price").quantile(lit(0.25), QuantileInterpolOptions::Linear).alias("25%"),
        col("price").quantile(lit(0.50), QuantileInterpolOptions::Linear).alias("50%"),
        col("price").quantile(lit(0.75), QuantileInterpolOptions::Linear).alias("75%"),
        col("price").max().alias("max"),
    ])
    .collect()
    .unwrap();

summary
// Out:
// shape: (1, 9)
// ┌───────┬────────────┬──────────┬──────────┬───┬──────┬─────┬──────┬─────┐
// │ count ┆ null_count ┆ mean     ┆ std      ┆ … ┆ 25%  ┆ 50% ┆ 75%  ┆ max │
// │ ---   ┆ ---        ┆ ---      ┆ ---      ┆   ┆ ---  ┆ --- ┆ ---  ┆ --- │
// │ u32   ┆ u32        ┆ f64      ┆ f64      ┆   ┆ f64  ┆ f64 ┆ f64  ┆ f64 │
// ╞═══════╪════════════╪══════════╪══════════╪═══╪══════╪═════╪══════╪═════╡
// │ 15    ┆ 0          ┆ 1.453333 ┆ 0.645718 ┆ … ┆ 0.85 ┆ 1.5 ┆ 1.95 ┆ 2.5 │
// └───────┴────────────┴──────────┴──────────┴───┴──────┴─────┴──────┴─────┘

// %% [markdown]
// Use Polars to filter and sort the data

// %%
let fruits_means = fruits
    .clone()
    .lazy()
    .group_by([col("fruit")])
    .agg([col("price").mean().alias("avg_price")])
    .sort(["fruit"], Default::default())
    .collect()?;

let fruits_names: Vec<String> = fruits_means
    .column("fruit")?
    .str()?
    .into_no_null_iter()
    .map(|s| s.to_string())
    .collect();

let mean_prices: Vec<f64> = fruits_means
    .column("avg_price")?
    .f64()?
    .into_no_null_iter()
    .collect();

let chart = evcxr_figure((640, 480), move |root| {
    root.fill(&WHITE)?;
    
    let max_price = mean_prices.iter().cloned().fold(0.0, f64::max);
    let y_max = ((max_price * 1.1) * 4.0).ceil() / 4.0;
    let n = fruits_names.len();
    
    let mut ctx = ChartBuilder::on(&root)
        .x_label_area_size(50)
        .y_label_area_size(60)
        .margin(20)
        .caption("Average Fruit Prices", ("sans-serif", 24))
        .build_cartesian_2d(-0.5f64..(n as f64 - 0.5), 0.0f64..y_max)?;
    
    ctx.configure_mesh()
        .y_desc("Price ($)")
        .x_desc("fruit")
        .disable_x_mesh()
        .x_labels(n)
        .x_label_formatter(&|x| {
            let i = (x + 0.5) as usize;
            fruits_names.get(i).cloned().unwrap_or_default()
        })
        .draw()?;
    
    // Draw bars with gaps
    let bar_width = 0.6;
    ctx.draw_series(
        mean_prices.iter().enumerate().map(|(i, v)| {
            let center = i as f64;
            let x0 = center - bar_width / 2.0;
            let x1 = center + bar_width / 2.0;
            Rectangle::new(
                [(x0, 0.0), (x1, *v)],
                RGBColor(68, 114, 196).filled()
            )
        })
    )?;
    
    Ok(())
});

chart
// Out:
// <div style=""><svg width="640" height="480" viewBox="0 0 640 480" xmlns="http://www.w3.org/2000/svg">
// <rect x="0" y="0" width="640" height="480" opacity="1" fill="#FFFFFF" stroke="none"/>
// <text x="320" y="25" dy="0.76em" text-anchor="middle" font-family="sans-serif" font-size="19.35483870967742" opacity="1" fill="#000000">
// Average Fruit Prices
// </text>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="80" y1="409" x2="619" y2="409"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="80" y1="406" x2="619" y2="406"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="80" y1="402" x2="619" y2="402"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="80" y1="399" x2="619" y2="399"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="80" y1="395" x2="619" y2="395"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="80" y1="392" x2="619" y2="392"/>
// ...

// %%
fruits_means
// Out:
// shape: (3, 2)
// ┌────────┬───────────┐
// │ fruit  ┆ avg_price │
// │ ---    ┆ ---       │
// │ str    ┆ f64       │
// ╞════════╪═══════════╡
// │ apple  ┆ 1.18      │
// │ banana ┆ 1.74      │
// │ orange ┆ 1.44      │
// └────────┴───────────┘

// %% [markdown]
// Create a plot visualizing fruit prices over time

// %%
let apple_df = fruits
    .clone()
    .lazy()
    .filter(col("fruit").eq(lit("apple")))
    .sort(["year"], Default::default())
    .collect()?;

let apple_years: Vec<i32> = apple_df.column("year")?.i32()?.into_no_null_iter().collect();
let apple_vals: Vec<f64> = apple_df.column("price")?.f64()?.into_no_null_iter().collect();
let apple_prices: Vec<(i32, f64)> = apple_years.into_iter().zip(apple_vals).collect();

let banana_df = fruits
    .clone()
    .lazy()
    .filter(col("fruit").eq(lit("banana")))
    .sort(["year"], Default::default())
    .collect()?;

let banana_years: Vec<i32> = banana_df.column("year")?.i32()?.into_no_null_iter().collect();
let banana_vals: Vec<f64> = banana_df.column("price")?.f64()?.into_no_null_iter().collect();
let banana_prices: Vec<(i32, f64)> = banana_years.into_iter().zip(banana_vals).collect();

let orange_df = fruits
    .clone()
    .lazy()
    .filter(col("fruit").eq(lit("orange")))
    .sort(["year"], Default::default())
    .collect()?;

let orange_years: Vec<i32> = orange_df.column("year")?.i32()?.into_no_null_iter().collect();
let orange_vals: Vec<f64> = orange_df.column("price")?.f64()?.into_no_null_iter().collect();
let orange_prices: Vec<(i32, f64)> = orange_years.into_iter().zip(orange_vals).collect();

let chart = evcxr_figure((700, 450), move |root| {
    root.fill(&WHITE)?;
    
    let mut ctx = ChartBuilder::on(&root)
        .x_label_area_size(40)
        .y_label_area_size(50)
        .margin(20)
        .caption("Fruit Prices Over Time", ("sans-serif", 24))
        .build_cartesian_2d(2017i32..2023i32, 0.0f64..3.0f64)?;
    
    ctx.configure_mesh()
        .x_desc("Year")
        .y_desc("Price ($)")
        .x_labels(6)
        .draw()?;
    
    // Apple - Blue
    ctx.draw_series(LineSeries::new(apple_prices.clone(), &BLUE))?
        .label("apple")
        .legend(|(x, y)| PathElement::new(vec![(x, y), (x + 20, y)], &BLUE));
    
    // Banana - Orange
    ctx.draw_series(LineSeries::new(banana_prices.clone(), &RGBColor(255, 165, 0)))?
        .label("banana")
        .legend(|(x, y)| PathElement::new(vec![(x, y), (x + 20, y)], &RGBColor(255, 165, 0)));
    
    // Orange - Green
    ctx.draw_series(LineSeries::new(orange_prices.clone(), &GREEN))?
        .label("orange")
        .legend(|(x, y)| PathElement::new(vec![(x, y), (x + 20, y)], &GREEN));
    
    ctx.configure_series_labels()
        .position(SeriesLabelPosition::UpperRight)
        .background_style(&WHITE.mix(0.8))
        .border_style(&BLACK)
        .draw()?;
    
    Ok(())
});

chart
// Out:
// <div style=""><svg width="700" height="450" viewBox="0 0 700 450" xmlns="http://www.w3.org/2000/svg">
// <rect x="0" y="0" width="700" height="450" opacity="1" fill="#FFFFFF" stroke="none"/>
// <text x="350" y="25" dy="0.76em" text-anchor="middle" font-family="sans-serif" font-size="19.35483870967742" opacity="1" fill="#000000">
// Fruit Prices Over Time
// </text>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="70" y1="389" x2="70" y2="50"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="171" y1="389" x2="171" y2="50"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="273" y1="389" x2="273" y2="50"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="374" y1="389" x2="374" y2="50"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="476" y1="389" x2="476" y2="50"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="577" y1="389" x2="577" y2="50"/>
// ...
